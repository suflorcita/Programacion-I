# %%
import pandas as pd
import os

# %%
# leo el csv de arbolado 
directorio = '../Data'
archivo = 'arbolado-en-espacios-verdes.csv'
fname = os.path.join(directorio,archivo)
df = pd.read_csv(fname)

# %%
df.head(5) # primeras cinco filas de Datos
# Out:
#         long        lat  id_arbol  altura_tot  diametro  inclinacio  \
# 0 -58.477564 -34.645015         1           6        35           0
# 1 -58.477559 -34.645047         2           6        35           0
# 2 -58.477551 -34.645091         3           6        35           0
# 3 -58.478129 -34.644567         4          17        50           0
# 4 -58.478121 -34.644598         5          17        50           0
#
#    id_especie                           nombre_com             nombre_cie  \
# 0          53  Washingtonia (Palmera washingtonia)  Washingtonia filifera
# 1          53  Washingtonia (Palmera washingtonia)  Washingtonia filifera
# 2          53  Washingtonia (Palmera washingtonia)  Washingtonia filifera
# 3          65                                 Ombú      Phytolacca dioica
# 4          65                                 Ombú      Phytolacca dioica
#
#                       tipo_folla                  espacio_ve  \
# ...

# %%
df.tail(5) # ultimas cinco filas de datos
# Out:
#             long        lat  id_arbol  altura_tot  diametro  inclinacio  \
# 51497 -58.505752 -34.562998     51725          15        30           0
# 51498 -58.507111 -34.565843     51726          13        31           0
# 51499 -58.475721 -34.565192     51727          11        28           0
# 51500 -58.507026 -34.565670     51728           5        32           0
# 51501 -58.506874 -34.565334     51729          10        35           0
#
#        id_especie                                       nombre_com  \
# 51497          45                                        Casuarina
# 51498          45                                        Casuarina
# 51499          17  Árbol del cielo (Ailanto o Árbol de los dioses)
# 51500         342                                           Ciprés
# 51501         342                                           Ciprés
#
#                      nombre_cie                     tipo_folla  \
# ...

# %%
df.columns # indice con el nombre de las columnas
# Out:
# Index(['long', 'lat', 'id_arbol', 'altura_tot', 'diametro', 'inclinacio',
#        'id_especie', 'nombre_com', 'nombre_cie', 'tipo_folla', 'espacio_ve',
#        'ubicacion', 'nombre_fam', 'nombre_gen', 'origen', 'coord_x',
#        'coord_y'],
#       dtype='object')

# %%
df.index # indice correspondiente a la linea leida del archivo
# Out:
# RangeIndex(start=0, stop=51502, step=1)

# %%
df[['altura_tot', 'diametro', 'inclinacio']].describe() # inspeccionar los datos
# Out:
#          altura_tot      diametro    inclinacio
# count  51502.000000  51502.000000  51502.000000
# mean      12.167100     39.395616      3.472215
# std        7.640309     31.171205      7.039495
# min        0.000000      1.000000      0.000000
# 25%        6.000000     18.000000      0.000000
# 50%       11.000000     32.000000      0.000000
# 75%       18.000000     54.000000      5.000000
# max       54.000000    500.000000     90.000000

# %% [markdown]
# #### Selección

# %%
df['nombre_com'].unique() # columna con los nombres comunes de los árboles
# Out:
# array(['Washingtonia (Palmera washingtonia)', 'Ombú', 'Catalpa', 'Ceibo',
#        'Brachichiton (Árbol botella, Brachichito)', 'Álamo plateado',
#        'Acacia de constantinopla', 'Acacia', 'Roble sedoso (Grevillea)',
#        'Arce', 'Palo borracho rosado', 'Álamo negro del Canada',
#        'Jacarandá', 'Álamo carolina', 'Aguaribay', 'Paraíso',
#        'Espinillo (Aromo)', 'Eucalipto', 'Ciprés leylandi', 'Ciprés',
#        'No Determinable', 'Álamo', 'No Determinado', 'Cedro', 'Lapacho',
#        'Crataegus', 'Cedro de San Juan', 'Juniperus', 'Chamaecyparis',
#        'Álamo blanco piramidal', 'Podocarpus', 'Tuja', 'El chañar',
#        'Arce tridente', 'Citricos', 'Sauce', 'Viburnum dulce',
#        'Corona de cristo', 'Taxodium', 'Mirto', 'Árbol del humo',
#        'Celtis tala', 'Criptomeria (Cedro del Japón)', 'Coculus, Cóculo',
#        'Caoba del sur', 'Arce blanco', 'Malus', 'Agatis blanco',
#        'Cotoneaster', 'Fenix', 'Libocedro (Calocedro)', 'Callistemon',
# ...

# %%
df['nombre_com'] == 'Ombú' # cuales de la columna de nombres comunes se llaman "Ombú"
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 51497    False
# 51498    False
# 51499    False
# 51500    False
# 51501    False
# Name: nombre_com, Length: 51502, dtype: bool

# %%
(df['nombre_com'] == 'Ombú').sum() # suma de los True
# Out:
# 590

# %% [markdown]
# #### Series booleanas

# %%
df_jacarandas = df[df['nombre_com'] == 'Jacarandá'] # obtengo las filas que tienen como nombre común Jacarandá 
df_jacarandas
# Out:
#             long        lat  id_arbol  altura_tot  diametro  inclinacio  \
# 165   -58.468381 -34.664770       166           5        10           0
# 166   -58.468345 -34.664821       167           5        10           0
# 167   -58.468329 -34.664877       168           5        10           0
# 168   -58.468313 -34.664763       169           5        10           0
# 169   -58.468232 -34.664830       170           5        10           0
# ...          ...        ...       ...         ...       ...         ...
# 51104 -58.377093 -34.635614     51332           7        97           4
# 51172 -58.477114 -34.673945     51400           8        28           8
# 51180 -58.487435 -34.597608     51408           2        30           0
# 51207 -58.456264 -34.685345     51435           3        10           0
# 51375 -58.415127 -34.569823     51603          17        40          20
#
#        id_especie nombre_com             nombre_cie  \
# ...
